# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from matplotlib import font_manager, rc

# %%
rc('font', family='gulim')#Windows

# %%
joined_test_data = pd.read_csv('./joined_test_data.csv', index_col=0)

# %%
yes_test = joined_test_data[joined_test_data['is_applied'] == 1]
yes_test
# Out:
#          user_id  bank_id  product_id  loan_limit  loan_rate  insert_weekday  \
# 3         545882       54         235   7000000.0       16.5               3
# 5         545882       23         236  21000000.0       15.5               1
# 6         545882       23         108  21000000.0       16.1               1
# 11        545882       38         223  10000000.0       17.4               1
# 12        545882       17          19  10000000.0       16.4               1
# ...          ...      ...         ...         ...        ...             ...
# 9875655   818151        1          61  12000000.0       15.4               0
# 9875656    43054        6          36  14000000.0       18.4               0
# 9875657   508855       29          75  18000000.0        9.4               0
# 9875658   508855       29          75  18000000.0        9.4               0
# 9875659   508855       29         180  18000000.0        9.4               0
#
# ...

# %%
yes_test.columns
# Out:
# Index(['user_id', 'bank_id', 'product_id', 'loan_limit', 'loan_rate',
#        'insert_weekday', 'age', 'age_group', 'gender', 'credit_score',
#        'yearly_income', 'income_type', 'years_of_service', 'months_of_service',
#        'employment_type', 'houseown_type', 'desired_amount', 'purpose',
#        'personal_rehabilitation_yn', 'personal_rehabilitation_complete_yn',
#        'existing_loan_cnt', 'existing_loan_amt', 'event1', 'event2', 'event3',
#        'event4', 'event5', 'event6', 'event7', 'event8', 'event9', 'event10',
#        'event11', 'is_applied'],
#       dtype='object')

# %%
predicted_result = pd.read_csv('./predicted_result.csv', index_col=0)

# %%
yes_predicted = predicted_result[predicted_result['predicted_is_applied'] == 1]
yes_predicted
# Out:
#          user_id  bank_id  product_id  loan_limit  loan_rate  insert_weekday  \
# 0         430982        7         191  42000000.0       13.6               1
# 1         430982       25         169  24000000.0       17.9               1
# 2         430982        2           7  24000000.0       18.5               1
# 3         430982        4         268  29000000.0       10.8               1
# 5         430982       35         168  21000000.0       15.2               1
# ...          ...      ...         ...         ...        ...             ...
# 3163524   876482       42         216  10000000.0       14.6               4
# 3163525    31658       29         265  30000000.0       10.2               4
# 3163527    31658       29          20  30000000.0        9.9               4
# 3163531    31658        1           1  50000000.0       12.4               4
# 3163533    31658        4          42  45000000.0        4.8               4
#
# ...

# %%
yes_predicted
# Out:
#          user_id  bank_id  product_id  loan_limit  loan_rate  insert_weekday  \
# 0         430982        7         191  42000000.0       13.6               1
# 1         430982       25         169  24000000.0       17.9               1
# 2         430982        2           7  24000000.0       18.5               1
# 3         430982        4         268  29000000.0       10.8               1
# 5         430982       35         168  21000000.0       15.2               1
# ...          ...      ...         ...         ...        ...             ...
# 3163524   876482       42         216  10000000.0       14.6               4
# 3163525    31658       29         265  30000000.0       10.2               4
# 3163527    31658       29          20  30000000.0        9.9               4
# 3163531    31658        1           1  50000000.0       12.4               4
# 3163533    31658        4          42  45000000.0        4.8               4
#
# ...

# %%
need_columns = ['loan_rate', 'credit_score', 'loan_limit', 'product_id', 'desired_amount', 'bank_id', 'yearly_income',
                'age', 'existing_loan_amt', 'event7', 'event11', 'income_type', 'event6', 'existing_loan_cnt', 'event5',
                'months_of_service', 'purpose', 'event2', 'event8', 'event4', 'event3']

# %%
gh_columns = ['existing_loan_amt', 'loan_limit', 'desired_amount', 'event11', 'event3', 'existing_loan_cnt', 'purpose']

# %% [markdown]
# ---

# %% [markdown]
# 대출 상품 관련 feature
#
# 1.loan_rate
#
# 3.loan_limit
#
# 4.product_id
#
# 6.bank_id

# %%
product_columns = ['bank_id', 'product_id', 'loan_rate', 'loan_limit']

# %%
t_product = yes_test[product_columns]
t_product['loan_limit'] = t_product['loan_limit']/10000
t_product
# Out:
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\2896753771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_product['loan_limit'] = t_product['loan_limit']/10000
#          bank_id  product_id  loan_rate  loan_limit
# 3             54         235       16.5       700.0
# 5             23         236       15.5      2100.0
# 6             23         108       16.1      2100.0
# 11            38         223       17.4      1000.0
# 12            17          19       16.4      1000.0
# ...          ...         ...        ...         ...
# 9875655        1          61       15.4      1200.0
# 9875656        6          36       18.4      1400.0
# 9875657       29          75        9.4      1800.0
# ...

# %%
p_product = yes_predicted[product_columns]
p_product['loan_limit'] = p_product['loan_limit']/10000
p_product
# Out:
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\2412565270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_product['loan_limit'] = p_product['loan_limit']/10000
#          bank_id  product_id  loan_rate  loan_limit
# 0              7         191       13.6      4200.0
# 1             25         169       17.9      2400.0
# 2              2           7       18.5      2400.0
# 3              4         268       10.8      2900.0
# 5             35         168       15.2      2100.0
# ...          ...         ...        ...         ...
# 3163524       42         216       14.6      1000.0
# 3163525       29         265       10.2      3000.0
# 3163527       29          20        9.9      3000.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# 유저 스펙 관련 feature
#
# 2.credit_score
#
# 5.desired_amount
#
# 7.yearly_income
#
# 8.age
#
# 9.existing_loan_amt
#
# 12.income_type
#
# 14.existing_loan_cnt
#
# 16.months_of_service
#
# 17.purpose

# %%
spec_columns = ['age', 'credit_score', 'purpose', 'desired_amount', 'income_type', 'yearly_income',
                'months_of_service', 'existing_loan_cnt', 'existing_loan_amt']

# %%
t_spec = yes_test[spec_columns]
t_spec['desired_amount'] = t_spec['desired_amount']/10000
t_spec['yearly_income'] = t_spec['yearly_income']/10000
t_spec['existing_loan_amt'] = t_spec['existing_loan_amt']/10000
t_spec
# Out:
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\3316410275.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_spec['desired_amount'] = t_spec['desired_amount']/10000
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\3316410275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_spec['yearly_income'] = t_spec['yearly_income']/10000
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\3316410275.py:4: SettingWithCopyWarning:
# ...

# %%
p_spec = yes_predicted[spec_columns]
p_spec['desired_amount'] = p_spec['desired_amount']/10000
p_spec['yearly_income'] = p_spec['yearly_income']/10000
p_spec['existing_loan_amt'] = p_spec['existing_loan_amt']/10000
p_spec
# Out:
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\3913242774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_spec['desired_amount'] = p_spec['desired_amount']/10000
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\3913242774.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_spec['yearly_income'] = p_spec['yearly_income']/10000
# C:\Users\1kg\AppData\Local\Temp\ipykernel_20356\3913242774.py:4: SettingWithCopyWarning:
# ...

# %% [markdown]
# ---

# %% [markdown]
# 로그 데이터 관련 feature
#
# 10.event7 (한도조회 결과 확인)
#
# 11.event11 (KCB 신용정보 조회)
#
# 13.event6 (본인인증 완료)
#
# 15.event5 (한도조회 시작하기 버튼 클릭)
#
# 18.event2 (핀다 앱 실행)
#
# 19.event8 (대출관리 서비스 이용)
#
# 20.event4 (한도조회 인트로 페이지 조회)
#
# 21.event3 (핀다 앱 로그인)

# %%
log_columns = ['event2', 'event3', 'event4', 'event5', 'event6', 'event7', 'event8', 'event11']

# %%
t_log = yes_test[log_columns]
t_log
# Out:
#          event2  event3  event4  event5  event6  event7  event8  event11
# 3          20.0    19.0    14.0    19.0    12.0    21.0     0.0      0.0
# 5          20.0    19.0    14.0    19.0    12.0    21.0     0.0      0.0
# 6          20.0    19.0    14.0    19.0    12.0    21.0     0.0      0.0
# 11         20.0    19.0    14.0    19.0    12.0    21.0     0.0      0.0
# 12         20.0    19.0    14.0    19.0    12.0    21.0     0.0      0.0
# ...         ...     ...     ...     ...     ...     ...     ...      ...
# 9875655     2.0     2.0     2.0     3.0     2.0     5.0     2.0      3.0
# 9875656     4.0     0.0     1.0     1.0     1.0     1.0     0.0      0.0
# 9875657    11.0     0.0     6.0     8.0     3.0    17.0     5.0      6.0
# 9875658    11.0     0.0     6.0     8.0     3.0    17.0     5.0      6.0
# 9875659    11.0     0.0     6.0     8.0     3.0    17.0     5.0      6.0
#
# [549665 rows x 8 columns]

# %%
p_log = yes_predicted[log_columns]
p_log
# Out:
#          event2  event3  event4  event5  event6  event7  event8  event11
# 0          42.0     0.0    16.0    50.0    15.0    50.0     1.0      2.0
# 1          42.0     0.0    16.0    50.0    15.0    50.0     1.0      2.0
# 2          42.0     0.0    16.0    50.0    15.0    50.0     1.0      2.0
# 3          42.0     0.0    16.0    50.0    15.0    50.0     1.0      2.0
# 5          42.0     0.0    16.0    50.0    15.0    50.0     1.0      2.0
# ...         ...     ...     ...     ...     ...     ...     ...      ...
# 3163524     2.0     0.0     2.0     1.0     1.0     1.0     3.0      1.0
# 3163525     0.0     0.0     1.0     1.0     1.0     1.0     0.0      0.0
# 3163527     0.0     0.0     1.0     1.0     1.0     1.0     0.0      0.0
# 3163531     0.0     0.0     1.0     1.0     1.0     1.0     0.0      0.0
# 3163533     0.0     0.0     1.0     1.0     1.0     1.0     0.0      0.0
#
# [778346 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# product

# %%
sns.jointplot(data = p_product, x = 'loan_rate', y = 'loan_limit', kind = 'reg', ylim = [0, 2000])

# %%
sns.pairplot(p_product, height = 2)

# %% [markdown]
# ---

# %% [markdown]
# gh_column

# %% [markdown]
# gh_columns = ['existing_loan_amt', 'loan_limit', 'desired_amount', 'event11', 'event3', 'existing_loan_cnt', 'purpose']
# product
# spec
# log

# %% [markdown]
# existing_loan_cnt	existing_loan_amt

# %%
sns.jointplot(data = p_spec, x = 'existing_loan_cnt', y = 'existing_loan_amt', kind = 'scatter', xlim=[0,10], ylim=[0,30000])

# %%
sns.boxplot(data = p_spec['desired_amount'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# loan limit 이나 existing loan amt와 같이 음액적인 부분에 대해서는 group을 지어야할 것 같음

# %%
sns.boxplot(data = p_log)
# Out:
# <AxesSubplot: >

# %%
sns.countplot(data = p_spec, x = "purpose")
# Out:
# <AxesSubplot: xlabel='purpose', ylabel='count'>

# %% [markdown]
# event와 is_applied와의 관계 reg로 나타낼 수 있지 않을까?

# %%
gh_columns = ['existing_loan_amt', 'loan_limit', 'desired_amount', 'event11', 'event3', 'existing_loan_cnt', 'purpose']

# %%
sns.countplot(data = p_spec, x = "existing_loan_cnt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 sns.countplot(data = p_spec, x = "existing_loan_cnt").set_xticks(np.arange(0, len(existing_loan_cnt.index) + 1, 10))
#
# NameError: name 'np' is not defined

# %%
spec_ela = p_spec['existing_loan_amt']
spec_ela
# Out:
# 0          1500.0
# 1          1500.0
# 2          1500.0
# 3          1500.0
# 5          1500.0
#             ...
# 3163524    2300.0
# 3163525       0.0
# 3163527       0.0
# 3163531       0.0
# 3163533       0.0
# Name: existing_loan_amt, Length: 778346, dtype: float64

# %%
sns.barplot(data = spec_ela)
# Out:
# <AxesSubplot: >
